# %%
import os
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI
from langchain_neo4j import Neo4jGraph
from langchain_core.documents import Document
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain_openai import ChatOpenAI
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
from dotenv import load_dotenv

# %%
# Load .env file
load_dotenv()

# Read environment variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORDD = os.getenv("NEO4J_PASSWORDD")
NEO4J_DATABASE1 = os.getenv("NEO4J_DATABASE1")
NEO4J_DATABASE2 = os.getenv("NEO4J_DATABASE2")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
graph = Neo4jGraph(
    url=NEO4J_URL,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORDD,
    database=NEO4J_DATABASE2,
    enhanced_schema=True
)
# Out:
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 42N00} {gql_status_description: error: syntax error or access rule violation - graph reference not found. A graph reference with the name `pdfs` was not found. Verify that the spelling is correct.} {message: 42N00: A graph reference with the name `pdfs` was not found. Verify that the spelling is correct.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 graph = Neo4jGraph(
#       2     url=NEO4J_URL,
#       3     username=NEO4J_USERNAME,
#       4     password=NEO4J_PASSWORDD,
#       5     database=NEO4J_DATABASE2,
#       6     enhanced_schema=True
#       7 )
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/langchain_neo4j/graphs/neo4j_graph.py:180, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     174 if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
#     175     raise ValueError(
#     176         "Could not use APOC procedures. "
#     177         "Please ensure the APOC plugin is installed in Neo4j and that "
#     178         "'apoc.meta.data()' is allowed in Neo4j configuration "
#     179     )
# --> 180 raise e
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/langchain_neo4j/graphs/neo4j_graph.py:172, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     170 if refresh_schema:
#     171     try:
# --> 172         self.refresh_schema()
#     173     except neo4j.exceptions.ClientError as e:
#     174         if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/langchain_neo4j/graphs/neo4j_graph.py:278, in Neo4jGraph.refresh_schema(self)
#     271 """
#     272 Refreshes the Neo4j graph schema information.
#     273
#     274 Raises:
#     275     RuntimeError: If the connection has been closed.
#     276 """
#     277 self._check_driver_state()
# --> 278 self.structured_schema = get_structured_schema(
#     279     driver=self._driver,
#     280     is_enhanced=self._enhanced_schema,
#     281     database=self._database,
#     282     timeout=self.timeout,
#     283     sanitize=self.sanitize,
#     284 )
#     285 self.schema = format_schema(
#     286     schema=self.structured_schema, is_enhanced=self._enhanced_schema
#     287 )
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j_graphrag/schema.py:289, in get_structured_schema(driver, is_enhanced, database, timeout, sanitize)
#     228 def get_structured_schema(
#     229     driver: neo4j.Driver,
#     230     is_enhanced: bool = False,
#    (...)    233     sanitize: bool = False,
#     234 ) -> dict[str, Any]:
#     235     """
#     236     Returns the structured schema of the graph.
#     237
#    (...)    285         dict[str, Any]: the graph schema information in a structured format.
#     286     """
#     287     node_properties = [
#     288         data["output"]
# --> 289         for data in query_database(
#     290             driver=driver,
#     291             query=NODE_PROPERTIES_QUERY,
#     292             params={
#     293                 "EXCLUDED_LABELS": EXCLUDED_LABELS
#     294                 + [BASE_ENTITY_LABEL, BASE_KG_BUILDER_LABEL]
#     295             },
#     296             database=database,
#     297             timeout=timeout,
#     298             sanitize=sanitize,
#     299         )
#     300     ]
#     302     rel_properties = [
#     303         data["output"]
#     304         for data in query_database(
#    (...)    311         )
#     312     ]
#     314     relationships = [
#     315         data["output"]
#     316         for data in query_database(
#    (...)    326         )
#     327     ]
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j_graphrag/schema.py:164, in query_database(driver, query, params, session_params, database, timeout, sanitize)
#     143 """
#     144 Queries the database.
#     145
#    (...)    161     list[dict[str, Any]]: the result of the query in json format.
#     162 """
#     163 if not session_params:
# --> 164     data = driver.execute_query(
#     165         Query(text=query, timeout=timeout),
#     166         database_=database,
#     167         parameters_=params,
#     168     )
#     169     json_data = [r.data() for r in data.records]
#     170     if sanitize:
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/driver.py:978, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     974     raise ValueError(
#     975         f"Invalid routing control value: {routing_!r}"
#     976     )
#     977 with session._pipelined_begin:
# --> 978     return session._run_transaction(
#     979         access_mode,
#     980         TelemetryAPI.DRIVER,
#     981         work,
#     982         (query_str, parameters, result_transformer_),
#     983         {},
#     984     )
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:588, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     586 tx = self._transaction
#     587 try:
# --> 588     result = transaction_function(tx, *args, **kwargs)
#     589 except asyncio.CancelledError:
#     590     # if cancellation callback has not been called yet:
#     591     if self._transaction is not None:
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_work/query.py:144, in unit_of_work.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     143 def wrapped(*args, **kwargs):
# --> 144     return f(*args, **kwargs)
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/driver.py:1314, in _work(tx, query, parameters, transformer)
#    1308 def _work(
#    1309     tx: ManagedTransaction,
#    1310     query: te.LiteralString,
#    1311     parameters: dict[str, t.Any],
#    1312     transformer: t.Callable[[Result], t.Union[_T]],
#    1313 ) -> _T:
# -> 1314     res = tx.run(query, parameters)
#    1315     return transformer(res)
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/work/transaction.py:206, in TransactionBase.run(self, query, parameters, **kwparameters)
#     203 self._results.append(result)
#     205 parameters = dict(parameters or {}, **kwparameters)
# --> 206 result._tx_ready_run(query, parameters)
#     208 return result
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/work/result.py:177, in Result._tx_ready_run(self, query, parameters)
#     173 def _tx_ready_run(self, query, parameters):
#     174     # BEGIN+RUN does not carry any extra on the RUN message.
#     175     # BEGIN {extra}
#     176     # RUN "query" {parameters} {extra}
# --> 177     self._run(query, parameters, None, None, None, None, None, None)
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/work/result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/work/result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_common.py:193, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     191 def inner(*args, **kwargs):
#     192     try:
# --> 193         func(*args, **kwargs)
#     194     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     195         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt.py:863, in Bolt.fetch_message(self)
#     859 # Receive exactly one message
#     860 tag, fields = self.inbox.pop(
#     861     hydration_hooks=self.responses[0].hydration_hooks
#     862 )
# --> 863 res = self._process_message(tag, fields)
#     864 self.idle_since = monotonic()
#     865 return res
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File /home/GraphRAG/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_common.py:263, in Response.on_failure(self, metadata)
#     261 handler = self.handlers.get("on_summary")
#     262 Util.callback(handler)
# --> 263 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Database.DatabaseNotFound} {message: Graph not found: pdfs}

# %%
print("Clearing existing graph for a fresh start...")
graph.query("MATCH (n) DETACH DELETE n")
# Out:
# Clearing existing graph for a fresh start...
# []

# %%
graph.refresh_schema()
print(graph.schema)
# Out:
# Node properties:
# - **Document**
#   - `id`: STRING Example: "9b2e3f806199be76c6b831ad6b4639be"
#   - `text`: STRING Available options: ['Alen  Sultanic    FF  Swipe  File  Part  1       C', 'it   becomes   a   shortcut   to   ___________    ', 'And  it  has  nothing  to  do  with  your  _______', 'All   that   and   more   will   happen   for   yo', 'you   know   how   to   ________________   …     Y', '______________     And   Im   not   the   only   o', 'TIMELINE  LANGUAGE   First  you’ll___,  then  once', 'So   after   you   know   how   to   ______,   ___', 'ASSUMPTIVE  QUESTIONS   They  always  open  with  ', "OPENERS    The  Two  Types  of  Coaches   There's "]
#   - `creator`: STRING Available options: ['PyPDF']
#   - `creationdate`: STRING Available options: ['']
#   - `producer`: STRING Available options: ['Skia/PDF m134 Google Docs Renderer']
#   - `source`: STRING Available options: ['pdfs/1. Copywriting Swipe Files (Alen).pdf']
#   - `total_pages`: INTEGER Min: 83, Max: 83
#   - `page`: INTEGER Min: 0, Max: 6
#   - `title`: STRING Available options: ['Copywriting Swipe Files (Alen)']
#   - `page_label`: STRING Available options: ['1', '2', '3', '4', '5', '6', '7']
# - **Person**
#   - `id`: STRING Available options: ['Alen Sultanic', 'You', 'Im', 'I', '____________________', 'Anyone']
# - **Timeperiod**
#   - `id`: STRING Available options: ['In The Next 7 Minutes']
# - **Concept**
#   - `id`: STRING Example: "Show You _____________ That Will ___________ And F"
# - **Event**
#   - `id`: STRING Example: "When You First Started"
# - **Action**
#   - `id`: STRING Example: "_________"
# - **Word**
#   - `id`: STRING Example: "You"
# - **Thing**
#   - `id`: STRING Available options: ['______________']
# - **Value**
#   - `id`: STRING Available options: ['______', '_______', '________To', '_________To', '__________']
# - **Video**
#   - `id`: STRING Available options: ['Short Video']
# - **Process**
#   - `id`: STRING Available options: ["First You'Ll___", 'Then Once You Have _____', 'Then What We Do Next Is _________', 'Then Once We Have All That, The Next Thing We Do I']
# - **Outcome**
#   - `id`: STRING Available options: ["Then You'Ll Be Able To ______", 'So You Can Finally ______', 'Become __________', 'That I ______', "You'Ll See How Easy It Is To ______", "Then You'Ll Be Able To ______ For Good."]
# - **Constraint**
#   - `id`: STRING Available options: ['Without Ever Having To _____']
# - **Condition**
#   - `id`: STRING Available options: ['And Once You Do _____']
# - **Place**
#   - `id`: STRING Available options: ['Members Area']
# - **Media**
#   - `id`: STRING Available options: ['This Video']
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Person)
# (:Document)-[:MENTIONS]->(:Document)
# (:Document)-[:MENTIONS]->(:Timeperiod)
# (:Document)-[:MENTIONS]->(:Concept)
# (:Document)-[:MENTIONS]->(:Word)
# (:Document)-[:MENTIONS]->(:Action)
# (:Document)-[:MENTIONS]->(:Event)
# (:Document)-[:MENTIONS]->(:Media)
# (:Document)-[:MENTIONS]->(:Value)
# (:Document)-[:MENTIONS]->(:Thing)
# (:Document)-[:MENTIONS]->(:Video)
# (:Document)-[:MENTIONS]->(:Process)
# (:Document)-[:MENTIONS]->(:Outcome)
# (:Document)-[:MENTIONS]->(:Constraint)
# (:Document)-[:MENTIONS]->(:Condition)
# (:Document)-[:MENTIONS]->(:Place)
# (:Document)-[:CONTAINS]->(:Document)
# (:Document)-[:CONTAINS]->(:Concept)
# (:Person)-[:AUTHOR]->(:Document)
# (:Person)-[:KNOWS]->(:Concept)
# (:Person)-[:KNOWS]->(:Value)
# (:Person)-[:ALLOWS]->(:Concept)
# (:Person)-[:KNEW]->(:Concept)
# (:Person)-[:FREED_FROM]->(:Concept)
# (:Person)-[:FREED_FROM]->(:Action)
# (:Person)-[:FREED_FROM]->(:Word)
# (:Person)-[:IS_WATCHING]->(:Event)
# (:Person)-[:IS_WATCHING]->(:Media)
# (:Person)-[:PERFORMS]->(:Action)
# (:Person)-[:PERFORMS]->(:Concept)
# (:Person)-[:CAN_EXPERIENCE]->(:Concept)
# (:Person)-[:LOOKS_AT]->(:Concept)
# (:Person)-[:HAS_KNOWLEDGE]->(:Concept)
# (:Person)-[:FOLLOWS]->(:Word)
# (:Person)-[:SHOWS]->(:Concept)
# (:Person)-[:TEACHES]->(:Concept)
# (:Person)-[:MADE]->(:Video)
# (:Person)-[:CREATED]->(:Action)
# (:Concept)-[:ASSOCIATED_WITH]->(:Concept)
# (:Concept)-[:HAPPENS_FOR]->(:Person)
# (:Concept)-[:HAPPENS_FOR]->(:Word)
# (:Concept)-[:BECOMES]->(:Concept)
# (:Concept)-[:GIVES]->(:Concept)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Person)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Word)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Concept)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Action)
# (:Concept)-[:FREES_FROM]->(:Concept)
# (:Concept)-[:ALLOWS]->(:Concept)
# (:Concept)-[:ALLOWS]->(:Person)
# (:Concept)-[:ALLOWS]->(:Word)
# (:Concept)-[:TAUGHT_TO]->(:Person)
# (:Concept)-[:DESCRIBES]->(:Concept)
# (:Concept)-[:PREVENTS]->(:Concept)
# (:Concept)-[:PREVENTS]->(:Action)
# (:Concept)-[:NOT_FAULT_OF]->(:Person)
# (:Concept)-[:NOT_FAULT_OF]->(:Word)
# (:Concept)-[:HAPPENS_IN]->(:Concept)
# (:Concept)-[:HAPPENS_IN]->(:Event)
# (:Concept)-[:CAUSES]->(:Concept)
# (:Concept)-[:CAUSES]->(:Value)
# (:Concept)-[:FREES]->(:Person)
# (:Concept)-[:FREES]->(:Word)
# (:Concept)-[:WITHOUT]->(:Concept)
# (:Concept)-[:FOLLOWS]->(:Word)
# (:Concept)-[:LEADS_TO]->(:Event)
# (:Concept)-[:LEADS_TO]->(:Concept)
# (:Concept)-[:TURNS_INTO]->(:Concept)
# (:Concept)-[:GIVEN_TO]->(:Person)
# (:Concept)-[:GIVEN_TO]->(:Word)
# (:Concept)-[:ENABLES]->(:Concept)
# (:Concept)-[:REASON_FOR]->(:Action)
# (:Concept)-[:HAS_KNOWLEDGE]->(:Person)
# (:Concept)-[:HAS_KNOWLEDGE]->(:Word)
# (:Concept)-[:APPLIES_TO]->(:Person)
# (:Concept)-[:APPLIES_TO]->(:Word)
# (:Concept)-[:GENERATES]->(:Concept)
# (:Concept)-[:GENERATES]->(:Value)
# (:Concept)-[:EXAMPLE_OF]->(:Action)
# (:Concept)-[:CONTEXT]->(:Process)
# (:Concept)-[:PROVIDES]->(:Concept)
# (:Concept)-[:PROVIDES]->(:Action)
# (:Concept)-[:PROVIDES]->(:Value)
# (:Concept)-[:REQUIRES]->(:Concept)
# (:Concept)-[:RELATED_TO]->(:Concept)
# (:Concept)-[:HAS_FEATURE]->(:Concept)
# (:Concept)-[:HAS_METHOD]->(:Concept)
# (:Concept)-[:HAS_PART]->(:Concept)
# (:Concept)-[:IS_A]->(:Concept)
# (:Concept)-[:TRANSFORMS_TO]->(:Concept)
# (:Concept)-[:EXEMPLIFIES]->(:Concept)
# (:Concept)-[:INCLUDES]->(:Concept)
# (:Concept)-[:OPERATES_IN]->(:Concept)
# (:Concept)-[:MAKES]->(:Concept)
# (:Concept)-[:WATCHES]->(:Concept)
# (:Concept)-[:CAN_TRANSITION_TO]->(:Concept)
# (:Event)-[:ADDRESSES]->(:Concept)
# (:Event)-[:LASTS]->(:Concept)
# (:Event)-[:LASTS]->(:Event)
# (:Event)-[:PROMISES]->(:Concept)
# (:Event)-[:PROMISES_TO_HELP_REACH]->(:Concept)
# (:Event)-[:RESULTS_IN]->(:Outcome)
# (:Event)-[:RESULTS_IN]->(:Concept)
# (:Event)-[:LEADS_TO]->(:Action)
# (:Event)-[:LEADS_TO]->(:Event)
# (:Event)-[:LEADS_TO]->(:Concept)
# (:Event)-[:LEADS_TO]->(:Word)
# (:Event)-[:PART_OF]->(:Concept)
# (:Action)-[:FOLLOWS]->(:Word)
# (:Action)-[:LEADS_TO]->(:Event)
# (:Action)-[:ENABLES]->(:Concept)
# (:Action)-[:ENABLES]->(:Action)
# (:Action)-[:PERFORMED_BY]->(:Person)
# (:Action)-[:PERFORMED_BY]->(:Word)
# (:Action)-[:APPLIES_TO]->(:Concept)
# (:Action)-[:APPLIES_TO]->(:Value)
# (:Action)-[:ALLOWS]->(:Person)
# (:Action)-[:ENABLED_ACTION]->(:Concept)
# (:Action)-[:ENABLED_ACTION]->(:Action)
# (:Action)-[:TOOK]->(:Value)
# (:Action)-[:SCALED]->(:Value)
# (:Action)-[:AUTOMATED]->(:Value)
# (:Action)-[:ENABLED]->(:Outcome)
# (:Word)-[:KNOWS]->(:Concept)
# (:Word)-[:KNOWS]->(:Value)
# (:Word)-[:ALLOWS]->(:Concept)
# (:Word)-[:KNEW]->(:Concept)
# (:Word)-[:FREED_FROM]->(:Concept)
# (:Word)-[:FREED_FROM]->(:Action)
# (:Word)-[:FREED_FROM]->(:Word)
# (:Word)-[:IS_WATCHING]->(:Event)
# (:Word)-[:IS_WATCHING]->(:Media)
# (:Word)-[:PERFORMS]->(:Action)
# (:Word)-[:CAN_EXPERIENCE]->(:Concept)
# (:Word)-[:LOOKS_AT]->(:Concept)
# (:Word)-[:HAS_KNOWLEDGE]->(:Concept)
# (:Word)-[:FOLLOWS]->(:Word)
# (:Word)-[:FOLLOWS]->(:Concept)
# (:Word)-[:FOLLOWS]->(:Action)
# (:Word)-[:FOLLOWS]->(:Person)
# (:Word)-[:LEADS_TO]->(:Event)
# (:Value)-[:GENERATES]->(:Concept)
# (:Value)-[:GENERATES]->(:Value)
# (:Video)-[:SHOWS]->(:Concept)
# (:Video)-[:SHOWS]->(:Action)
# (:Video)-[:SHOWS]->(:Word)
# (:Video)-[:SHOWS]->(:Value)
# (:Process)-[:NEXT]->(:Process)
# (:Process)-[:RESULTS_IN]->(:Outcome)
# (:Outcome)-[:CONDITION]->(:Constraint)
# (:Outcome)-[:RESULTS_IN]->(:Outcome)
# (:Outcome)-[:NEXT]->(:Process)
# (:Condition)-[:LEADS_TO]->(:Outcome)
# (:Media)-[:ADDRESSES]->(:Concept)
# (:Media)-[:LASTS]->(:Concept)
# (:Media)-[:LASTS]->(:Event)
# (:Media)-[:PROMISES]->(:Concept)
# (:Media)-[:PROMISES_TO_HELP_REACH]->(:Concept)

# %%
# 1. Initialize LLM + transformer
llm = ChatOpenAI(temperature=0, model_name="gpt-5-mini")
llm_transformer = LLMGraphTransformer(llm=llm)

# 2. Define your PDF list
pdf_files = [
    "pdfs/1. Copywriting Swipe Files (Alen).pdf",
    # "pdfs/2. Copywriting Swipe Files (Alen).pdf",
    # "pdfs/3. Copywriting Swipe Files (Alen).pdf",
    # "pdfs/4. FB Posts (Alen).pdf",
    # "pdfs/5. FB Posts (Alen).pdf",
]

# 3. Define splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,   # ~1000 tokens (balanced)
    chunk_overlap=150  # keeps context between chunks
)

# 4. Process each PDF separately
for pdf in pdf_files:
    loader = PyPDFLoader(pdf)
    pages = loader.load()

    # Split into chunks (Recursive handles pages seamlessly)
    chunks = splitter.split_documents(pages)
    print(f"{pdf} → {len(chunks)} chunks")


    # Convert chunks into graph docs
    graph_documents = []
    for i, chunk in enumerate(chunks, start=1):  # start=1 makes it 1-based index
        chunk_doc = [Document(
            page_content=chunk.page_content,
            metadata={"source": pdf, **chunk.metadata}  # preserve page info
        )]
        chunk_graph_docs = await llm_transformer.aconvert_to_graph_documents(chunk_doc)
        print(f"Converted chunk No.{i} out of {len(chunks)} to {len(chunk_graph_docs)} graph docs")
        graph_documents.extend(chunk_graph_docs)

        if i == 10:  # Limit to first 10 chunks for testing
            print("Reached 10 chunks, stopping further processing for this PDF.")
            break

    # Push into graph
    print(f"pushing {len(graph_documents)} graph docs to Neo4j...")
    graph.add_graph_documents(graph_documents, baseEntityLabel=True, include_source=True)

    print(f"Finished processing {pdf}")
# Out:
# pdfs/1. Copywriting Swipe Files (Alen).pdf → 154 chunks
# Converted chunk No.1 out of 154 to 1 graph docs
# Converted chunk No.2 out of 154 to 1 graph docs
# Converted chunk No.3 out of 154 to 1 graph docs
# Converted chunk No.4 out of 154 to 1 graph docs
# Converted chunk No.5 out of 154 to 1 graph docs
# Converted chunk No.6 out of 154 to 1 graph docs
# Converted chunk No.7 out of 154 to 1 graph docs
# Converted chunk No.8 out of 154 to 1 graph docs
# Converted chunk No.9 out of 154 to 1 graph docs
# Converted chunk No.10 out of 154 to 1 graph docs
# Reached 10 chunks, stopping further processing for this PDF.
# pushing 10 graph docs to Neo4j...
# Finished processing pdfs/1. Copywriting Swipe Files (Alen).pdf

# %%
# from langchain_core.documents import Document

# llm = ChatOpenAI(temperature=0, model_name="gpt-5")
# llm_transformer = LLMGraphTransformer(llm=llm)

# text = """
# Marie Curie, born in 1867, was a Polish and naturalised-French physicist and chemist who conducted pioneering research on radioactivity.
# She was the first woman to win a Nobel Prize, the first person to win a Nobel Prize twice, and the only person to win a Nobel Prize in two scientific fields.
# Her husband, Pierre Curie, was a co-winner of her first Nobel Prize, making them the first-ever married couple to win the Nobel Prize and launching the Curie family legacy of five Nobel Prizes.
# She was, in 1906, the first woman to become a professor at the University of Paris.
# """
# documents = [Document(page_content=text)]
# graph_documents = await llm_transformer.aconvert_to_graph_documents(documents)
# graph.add_graph_documents(graph_documents, baseEntityLabel=True, include_source=True)

# %%
graph.refresh_schema()
print(f"Graph Schema:{graph.schema}")
# Out:
# Graph Schema:Node properties:
# - **Document**
#   - `id`: STRING Example: "9b2e3f806199be76c6b831ad6b4639be"
#   - `text`: STRING Available options: ['Alen  Sultanic    FF  Swipe  File  Part  1       C', 'it   becomes   a   shortcut   to   ___________    ', 'And  it  has  nothing  to  do  with  your  _______', 'All   that   and   more   will   happen   for   yo', 'you   know   how   to   ________________   …     Y', '______________     And   Im   not   the   only   o', 'TIMELINE  LANGUAGE   First  you’ll___,  then  once', 'So   after   you   know   how   to   ______,   ___', 'ASSUMPTIVE  QUESTIONS   They  always  open  with  ', "OPENERS    The  Two  Types  of  Coaches   There's "]
#   - `creator`: STRING Available options: ['PyPDF']
#   - `creationdate`: STRING Available options: ['']
#   - `producer`: STRING Available options: ['Skia/PDF m134 Google Docs Renderer']
#   - `source`: STRING Available options: ['pdfs/1. Copywriting Swipe Files (Alen).pdf']
#   - `total_pages`: INTEGER Min: 83, Max: 83
#   - `page`: INTEGER Min: 0, Max: 6
#   - `title`: STRING Available options: ['Copywriting Swipe Files (Alen)']
#   - `page_label`: STRING Available options: ['1', '2', '3', '4', '5', '6', '7']
# - **Person**
#   - `id`: STRING Available options: ['Alen Sultanic', 'You', 'Im', 'I', '____________________', 'Anyone']
# - **Timeperiod**
#   - `id`: STRING Available options: ['In The Next 7 Minutes']
# - **Concept**
#   - `id`: STRING Example: "Show You _____________ That Will ___________ And F"
# - **Event**
#   - `id`: STRING Example: "When You First Started"
# - **Action**
#   - `id`: STRING Example: "_________"
# - **Word**
#   - `id`: STRING Example: "You"
# - **Thing**
#   - `id`: STRING Available options: ['______________']
# - **Value**
#   - `id`: STRING Available options: ['______', '_______', '________To', '_________To', '__________']
# - **Video**
#   - `id`: STRING Available options: ['Short Video']
# - **Process**
#   - `id`: STRING Available options: ["First You'Ll___", 'Then Once You Have _____', 'Then What We Do Next Is _________', 'Then Once We Have All That, The Next Thing We Do I']
# - **Outcome**
#   - `id`: STRING Available options: ["Then You'Ll Be Able To ______", 'So You Can Finally ______', 'Become __________', 'That I ______', "You'Ll See How Easy It Is To ______", "Then You'Ll Be Able To ______ For Good."]
# - **Constraint**
#   - `id`: STRING Available options: ['Without Ever Having To _____']
# - **Condition**
#   - `id`: STRING Available options: ['And Once You Do _____']
# - **Place**
#   - `id`: STRING Available options: ['Members Area']
# - **Media**
#   - `id`: STRING Available options: ['This Video']
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Person)
# (:Document)-[:MENTIONS]->(:Document)
# (:Document)-[:MENTIONS]->(:Timeperiod)
# (:Document)-[:MENTIONS]->(:Concept)
# (:Document)-[:MENTIONS]->(:Word)
# (:Document)-[:MENTIONS]->(:Action)
# (:Document)-[:MENTIONS]->(:Event)
# (:Document)-[:MENTIONS]->(:Media)
# (:Document)-[:MENTIONS]->(:Value)
# (:Document)-[:MENTIONS]->(:Thing)
# (:Document)-[:MENTIONS]->(:Video)
# (:Document)-[:MENTIONS]->(:Process)
# (:Document)-[:MENTIONS]->(:Outcome)
# (:Document)-[:MENTIONS]->(:Constraint)
# (:Document)-[:MENTIONS]->(:Condition)
# (:Document)-[:MENTIONS]->(:Place)
# (:Document)-[:CONTAINS]->(:Document)
# (:Document)-[:CONTAINS]->(:Concept)
# (:Person)-[:AUTHOR]->(:Document)
# (:Person)-[:KNOWS]->(:Concept)
# (:Person)-[:KNOWS]->(:Value)
# (:Person)-[:ALLOWS]->(:Concept)
# (:Person)-[:KNEW]->(:Concept)
# (:Person)-[:FREED_FROM]->(:Concept)
# (:Person)-[:FREED_FROM]->(:Action)
# (:Person)-[:FREED_FROM]->(:Word)
# (:Person)-[:IS_WATCHING]->(:Event)
# (:Person)-[:IS_WATCHING]->(:Media)
# (:Person)-[:PERFORMS]->(:Action)
# (:Person)-[:PERFORMS]->(:Concept)
# (:Person)-[:CAN_EXPERIENCE]->(:Concept)
# (:Person)-[:LOOKS_AT]->(:Concept)
# (:Person)-[:HAS_KNOWLEDGE]->(:Concept)
# (:Person)-[:FOLLOWS]->(:Word)
# (:Person)-[:SHOWS]->(:Concept)
# (:Person)-[:TEACHES]->(:Concept)
# (:Person)-[:MADE]->(:Video)
# (:Person)-[:CREATED]->(:Action)
# (:Concept)-[:ASSOCIATED_WITH]->(:Concept)
# (:Concept)-[:HAPPENS_FOR]->(:Person)
# (:Concept)-[:HAPPENS_FOR]->(:Word)
# (:Concept)-[:BECOMES]->(:Concept)
# (:Concept)-[:GIVES]->(:Concept)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Person)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Word)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Concept)
# (:Concept)-[:NOT_ASSOCIATED_WITH]->(:Action)
# (:Concept)-[:FREES_FROM]->(:Concept)
# (:Concept)-[:ALLOWS]->(:Concept)
# (:Concept)-[:ALLOWS]->(:Person)
# (:Concept)-[:ALLOWS]->(:Word)
# (:Concept)-[:TAUGHT_TO]->(:Person)
# (:Concept)-[:DESCRIBES]->(:Concept)
# (:Concept)-[:PREVENTS]->(:Concept)
# (:Concept)-[:PREVENTS]->(:Action)
# (:Concept)-[:NOT_FAULT_OF]->(:Person)
# (:Concept)-[:NOT_FAULT_OF]->(:Word)
# (:Concept)-[:HAPPENS_IN]->(:Concept)
# (:Concept)-[:HAPPENS_IN]->(:Event)
# (:Concept)-[:CAUSES]->(:Concept)
# (:Concept)-[:CAUSES]->(:Value)
# (:Concept)-[:FREES]->(:Person)
# (:Concept)-[:FREES]->(:Word)
# (:Concept)-[:WITHOUT]->(:Concept)
# (:Concept)-[:FOLLOWS]->(:Word)
# (:Concept)-[:LEADS_TO]->(:Event)
# (:Concept)-[:LEADS_TO]->(:Concept)
# (:Concept)-[:TURNS_INTO]->(:Concept)
# (:Concept)-[:GIVEN_TO]->(:Person)
# (:Concept)-[:GIVEN_TO]->(:Word)
# (:Concept)-[:ENABLES]->(:Concept)
# (:Concept)-[:REASON_FOR]->(:Action)
# (:Concept)-[:HAS_KNOWLEDGE]->(:Person)
# (:Concept)-[:HAS_KNOWLEDGE]->(:Word)
# (:Concept)-[:APPLIES_TO]->(:Person)
# (:Concept)-[:APPLIES_TO]->(:Word)
# (:Concept)-[:GENERATES]->(:Concept)
# (:Concept)-[:GENERATES]->(:Value)
# (:Concept)-[:EXAMPLE_OF]->(:Action)
# (:Concept)-[:CONTEXT]->(:Process)
# (:Concept)-[:PROVIDES]->(:Concept)
# (:Concept)-[:PROVIDES]->(:Action)
# (:Concept)-[:PROVIDES]->(:Value)
# (:Concept)-[:REQUIRES]->(:Concept)
# (:Concept)-[:RELATED_TO]->(:Concept)
# (:Concept)-[:HAS_FEATURE]->(:Concept)
# (:Concept)-[:HAS_METHOD]->(:Concept)
# (:Concept)-[:HAS_PART]->(:Concept)
# (:Concept)-[:IS_A]->(:Concept)
# (:Concept)-[:TRANSFORMS_TO]->(:Concept)
# (:Concept)-[:EXEMPLIFIES]->(:Concept)
# (:Concept)-[:INCLUDES]->(:Concept)
# (:Concept)-[:OPERATES_IN]->(:Concept)
# (:Concept)-[:MAKES]->(:Concept)
# (:Concept)-[:WATCHES]->(:Concept)
# (:Concept)-[:CAN_TRANSITION_TO]->(:Concept)
# (:Event)-[:ADDRESSES]->(:Concept)
# (:Event)-[:LASTS]->(:Concept)
# (:Event)-[:LASTS]->(:Event)
# (:Event)-[:PROMISES]->(:Concept)
# (:Event)-[:PROMISES_TO_HELP_REACH]->(:Concept)
# (:Event)-[:RESULTS_IN]->(:Outcome)
# (:Event)-[:RESULTS_IN]->(:Concept)
# (:Event)-[:LEADS_TO]->(:Action)
# (:Event)-[:LEADS_TO]->(:Event)
# (:Event)-[:LEADS_TO]->(:Concept)
# (:Event)-[:LEADS_TO]->(:Word)
# (:Event)-[:PART_OF]->(:Concept)
# (:Action)-[:FOLLOWS]->(:Word)
# (:Action)-[:LEADS_TO]->(:Event)
# (:Action)-[:ENABLES]->(:Concept)
# (:Action)-[:ENABLES]->(:Action)
# (:Action)-[:PERFORMED_BY]->(:Person)
# (:Action)-[:PERFORMED_BY]->(:Word)
# (:Action)-[:APPLIES_TO]->(:Concept)
# (:Action)-[:APPLIES_TO]->(:Value)
# (:Action)-[:ALLOWS]->(:Person)
# (:Action)-[:ENABLED_ACTION]->(:Concept)
# (:Action)-[:ENABLED_ACTION]->(:Action)
# (:Action)-[:TOOK]->(:Value)
# (:Action)-[:SCALED]->(:Value)
# (:Action)-[:AUTOMATED]->(:Value)
# (:Action)-[:ENABLED]->(:Outcome)
# (:Word)-[:KNOWS]->(:Concept)
# (:Word)-[:KNOWS]->(:Value)
# (:Word)-[:ALLOWS]->(:Concept)
# (:Word)-[:KNEW]->(:Concept)
# (:Word)-[:FREED_FROM]->(:Concept)
# (:Word)-[:FREED_FROM]->(:Action)
# (:Word)-[:FREED_FROM]->(:Word)
# (:Word)-[:IS_WATCHING]->(:Event)
# (:Word)-[:IS_WATCHING]->(:Media)
# (:Word)-[:PERFORMS]->(:Action)
# (:Word)-[:CAN_EXPERIENCE]->(:Concept)
# (:Word)-[:LOOKS_AT]->(:Concept)
# (:Word)-[:HAS_KNOWLEDGE]->(:Concept)
# (:Word)-[:FOLLOWS]->(:Word)
# (:Word)-[:FOLLOWS]->(:Concept)
# (:Word)-[:FOLLOWS]->(:Action)
# (:Word)-[:FOLLOWS]->(:Person)
# (:Word)-[:LEADS_TO]->(:Event)
# (:Value)-[:GENERATES]->(:Concept)
# (:Value)-[:GENERATES]->(:Value)
# (:Video)-[:SHOWS]->(:Concept)
# (:Video)-[:SHOWS]->(:Action)
# (:Video)-[:SHOWS]->(:Word)
# (:Video)-[:SHOWS]->(:Value)
# (:Process)-[:NEXT]->(:Process)
# (:Process)-[:RESULTS_IN]->(:Outcome)
# (:Outcome)-[:CONDITION]->(:Constraint)
# (:Outcome)-[:RESULTS_IN]->(:Outcome)
# (:Outcome)-[:NEXT]->(:Process)
# (:Condition)-[:LEADS_TO]->(:Outcome)
# (:Media)-[:ADDRESSES]->(:Concept)
# (:Media)-[:LASTS]->(:Concept)
# (:Media)-[:LASTS]->(:Event)
# (:Media)-[:PROMISES]->(:Concept)
# (:Media)-[:PROMISES_TO_HELP_REACH]->(:Concept)
